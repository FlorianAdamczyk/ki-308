# %%
# --- Standard library ---
import random                                    # Python's built-in RNG

# --- Third-party libraries: numerical + plotting ---
import numpy as np                               # numerical computing
import matplotlib.pyplot as plt                  # plotting and visualization

from sklearn.datasets import fetch_california_housing

# --- scikit-learn: linear models ---
from sklearn.linear_model import (
    LinearRegression,                            # ordinary least squares (OLS, L2 loss)
    Lasso,                                       # L1-regularized linear regression (LASSO)
    LassoCV,                                     # LASSO with cross-validated regularization
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import random                                    # Python's built-in RNG
#       4 # --- Third-party libraries: numerical + plotting ---
# ----> 5 import numpy as np                               # numerical computing
#       6 import matplotlib.pyplot as plt                  # plotting and visualization
#       8 from sklearn.datasets import fetch_california_housing
#
# ModuleNotFoundError: No module named 'numpy'
